# %% [markdown]
# # Create Extra Visualizations

# %%
# import dependencies and data
import pandas as pd
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

df = pd.read_csv("../data/cities.csv")
df
# Out:
#      City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 0          0  jacareacanga           0      BR  1528902000        62  -6.22
# 1          1    kaitangata         100      NZ  1528905304        94 -46.28
# 2          2      goulburn          20      AU  1528905078        91 -34.75
# 3          3          lata          76      IN  1528905305        89  30.78
# 4          4    chokurdakh           0      RU  1528905306        88  70.62
# ..       ...           ...         ...     ...         ...       ...    ...
# 542      542        scalea          36      IT  1528905631       100  39.82
# 543      543    san andres          68      PH  1528905632       100  13.32
# 544      544        muisne          92      EC  1528905633        84   0.61
# 545      545           ati          20      TD  1528905633        25  13.21
# 546      546      san luis           0      AR  1528905472        53 -33.30
#
#         Lng  Max Temp  Wind Speed
# ...

# %%
df['Latn'] = [float(lat) for lat in df['Lat']]
df['Lngn'] = [float(lng) for lng in df['Lng']]
df = df.dropna()
df
# Out:
#      City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 0          0  jacareacanga           0      BR  1528902000        62  -6.22
# 1          1    kaitangata         100      NZ  1528905304        94 -46.28
# 2          2      goulburn          20      AU  1528905078        91 -34.75
# 3          3          lata          76      IN  1528905305        89  30.78
# 4          4    chokurdakh           0      RU  1528905306        88  70.62
# ..       ...           ...         ...     ...         ...       ...    ...
# 542      542        scalea          36      IT  1528905631       100  39.82
# 543      543    san andres          68      PH  1528905632       100  13.32
# 544      544        muisne          92      EC  1528905633        84   0.61
# 545      545           ati          20      TD  1528905633        25  13.21
# 546      546      san luis           0      AR  1528905472        53 -33.30
#
#         Lng  Max Temp  Wind Speed   Latn    Lngn
# ...

# %%
# create scatter of latitude and longitude
xvals = df['Lng']
yvals = df['Lat']
plt.figure(figsize=(20,10))
ax = plt.axes(projection=ccrs.PlateCarree())
ax.stock_img()
ax.set_xticks([-180, -120, -60, 0, 60, 120, 180], crs=ccrs.PlateCarree())
ax.set_yticks([-90, -60, -30, 0, 30, 60, 90], crs=ccrs.PlateCarree())
plt.scatter(xvals,yvals,color='red')
plt.title('Latitude and Longitude of Locations Used')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.grid()
plt.savefig("latlngmap.png")
plt.show()

# %%
# create histogram of latitude
plt.figure(figsize=(20,10))
plt.hist(yvals)
plt.title('Histogram of Latitudes for Locations Used')
plt.xlabel('Latitude')
plt.ylabel('Frequency')
plt.xlim(-90,90)
plt.savefig("lathisto.png")
plt.show()
